# %%
# Imports 

import csv
import datetime as dt
import json
import os
import statistics
import time
import sys
import numpy as np
import pandas as pd
import requests
import datetime

pd.set_option("max_columns", 100)

# %% [markdown]
# Pulling 30,000 rows of data from steamspy and steampowered (steam store).

# %%
# set files and columns
download_path = 'Capstone-project'
steamspy_data = 'steamspy_data.csv'
steamspy_index = 'steamspy_index.txt'
steam_app_data = 'steampowered_app_data.csv'
steam_index = 'steampowered_index.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

steam_columns = [
   'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
   'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
   'supported_languages','pc_requirements', 'mac_requirements', 'linux_requirements',
   'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
   'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'recommendations',
   'achievements', 'release_date', 'content_descriptors'
]

# %%
## request 
def get_request(url, parameters=None):
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        print('No response, waiting 10 seconds...')
        time.sleep(10)
        print('Retrying.')
        return get_request(url, parameters)

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)
        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()
            

def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data

# %%
### the main function called to process data.  This will breakup the jobs into batches 
### and then grab data from those batches using the get_app_data function
def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):

    print('Starting at index {}:\n'.format(begin))
    now=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    count=0
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)        
        rel_path = os.path.join(download_path, data_filename)
        temp_path = os.path.join("{}/tmp/".format(download_path), "{}.{}_{}".format(data_filename,now,count))                          
        count=count+1
        
        print("\rWriting temp data")
        with open(temp_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            writer.writerows(app_data)
                
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
###functions we use to parse data from steampowered and steamspy.
###These functions pull a single games information based an app id that is passed to it
def parse_steam_request(appid, name):
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data

def parse_steamspy_request(appid, name):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters)
    return json_data

# %%
#pull data directly from steamspy.  Gets appid and game name.
url = "https://steamspy.com/api.php"

page=0
max_pages=30
app_list=pd.DataFrame()
while page<max_pages:
    parameters = {"request": "all","page":page}
    print("getting page {}?results=all&page={}".format(url,page))
    json_data = get_request(url, parameters=parameters)
   #print(json_data)
    if json_data:
        steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')
        tmp_app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)
        tmp_app_list.to_csv('app_list_page_{}.csv'.format(page), index=False)
        app_list = app_list.append(tmp_app_list)
    else:
        print("no data return")
    page=page+1
    time.sleep(60)

# %%
#pull data from CSV files instead of regenerating data.
csvpath="/Users/zig/Downloads//Project/csvfiles_backup/"
count=0
app_list=pd.DataFrame()
for filename in os.listdir(csvpath):
    if "app_list_page" in filename:
        full_path="{}{}".format(csvpath,filename)
        #print(full_path)
        tmp_list = pd.read_csv("{}{}".format(csvpath,filename))
        #print(tmp_list.head(5))
        app_list=app_list.append(tmp_list)
        count=count+1
print("Read {} csv files".format(count))
print("Number of rows  in app_list: {}".format(app_list.shape))
app_list=app_list.sort_values(by='appid')
# Out:
# Read 30 csv files
# Number of rows  in app_list: (30000, 2)

# %%
reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

###get steamspy data
process_batches(
    parser=parse_steamspy_request,
    app_list=app_list,
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    #end=30000,
    batchsize=100,
    pause=0.1,
    #end=10,
    #batchsize=5
)

# %%
reset_index(download_path, steam_index)
index = get_index(download_path, steam_index)

###get steampowered data
process_batches(
   parser=parse_steam_request,
   app_list=app_list,
   download_path=download_path,
   data_filename=steam_app_data,
   index_filename=steam_index,
   columns=steam_columns,
   begin=index,
   batchsize=100,
   pause=0.6,
   #end=10,
   #batchsize=5
)
# Out:
# Starting at index 0:
#
# Writing temp data
# Exported lines 0-99 to steampowered_app_data.csv. Batch 0 time: 0:01:42 (avg: 0:01:42, remaining: 8:29:28)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 100-199 to steampowered_app_data.csv. Batch 1 time: 0:02:42 (avg: 0:02:12, remaining: 10:57:32)
# Writing temp data
# Exported lines 200-299 to steampowered_app_data.csv. Batch 2 time: 0:01:35 (avg: 0:02:00, remaining: 9:54:01)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 300-399 to steampowered_app_data.csv. Batch 3 time: 0:03:31 (avg: 0:02:23, remaining: 11:45:25)
# Writing temp data9
# Exported lines 400-499 to steampowered_app_data.csv. Batch 4 time: 0:01:38 (avg: 0:02:14, remaining: 10:58:57)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 500-599 to steampowered_app_data.csv. Batch 5 time: 0:03:21 (avg: 0:02:25, remaining: 11:52:00)
# Writing temp data3
# Exported lines 600-699 to steampowered_app_data.csv. Batch 6 time: 0:01:39 (avg: 0:02:18, remaining: 11:17:20)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 700-799 to steampowered_app_data.csv. Batch 7 time: 0:03:21 (avg: 0:02:26, remaining: 11:53:28)
# Writing temp data5
# Exported lines 800-899 to steampowered_app_data.csv. Batch 8 time: 0:01:38 (avg: 0:02:21, remaining: 11:24:47)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 900-999 to steampowered_app_data.csv. Batch 9 time: 0:03:33 (avg: 0:02:28, remaining: 11:57:36)
# Writing temp data5
# Exported lines 1000-1099 to steampowered_app_data.csv. Batch 10 time: 0:01:37 (avg: 0:02:23, remaining: 11:32:54)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 1100-1199 to steampowered_app_data.csv. Batch 11 time: 0:03:25 (avg: 0:02:29, remaining: 11:55:25)
# Writing temp data1
# Exported lines 1200-1299 to steampowered_app_data.csv. Batch 12 time: 0:01:47 (avg: 0:02:25, remaining: 11:37:27)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 1300-1399 to steampowered_app_data.csv. Batch 13 time: 0:03:19 (avg: 0:02:29, remaining: 11:53:26)
# Writing temp data0
# Exported lines 1400-1499 to steampowered_app_data.csv. Batch 14 time: 0:01:36 (avg: 0:02:26, remaining: 11:34:03)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 1500-1599 to steampowered_app_data.csv. Batch 15 time: 0:03:22 (avg: 0:02:29, remaining: 11:48:19)
# Writing temp data7
# Exported lines 1600-1699 to steampowered_app_data.csv. Batch 16 time: 0:01:40 (avg: 0:02:26, remaining: 11:32:14)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data9
# Exported lines 1700-1799 to steampowered_app_data.csv. Batch 17 time: 0:03:24 (avg: 0:02:29, remaining: 11:44:56)
# Writing temp data4
# Exported lines 1800-1899 to steampowered_app_data.csv. Batch 18 time: 0:01:40 (avg: 0:02:27, remaining: 11:30:08)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 1900-1999 to steampowered_app_data.csv. Batch 19 time: 0:03:21 (avg: 0:02:30, remaining: 11:40:22)
# Writing temp data7
# Exported lines 2000-2099 to steampowered_app_data.csv. Batch 20 time: 0:01:42 (avg: 0:02:27, remaining: 11:27:13)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 2100-2199 to steampowered_app_data.csv. Batch 21 time: 0:03:23 (avg: 0:02:30, remaining: 11:36:27)
# Writing temp data0
# Exported lines 2200-2299 to steampowered_app_data.csv. Batch 22 time: 0:01:42 (avg: 0:02:28, remaining: 11:24:19)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 2300-2399 to steampowered_app_data.csv. Batch 23 time: 0:03:13 (avg: 0:02:30, remaining: 11:30:30)
# Writing temp data6
# Exported lines 2400-2499 to steampowered_app_data.csv. Batch 24 time: 0:01:37 (avg: 0:02:27, remaining: 11:18:23)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 2500-2599 to steampowered_app_data.csv. Batch 25 time: 0:03:34 (avg: 0:02:30, remaining: 11:27:44)
# Writing temp data2
# Exported lines 2600-2699 to steampowered_app_data.csv. Batch 26 time: 0:01:40 (avg: 0:02:28, remaining: 11:16:49)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 2700-2799 to steampowered_app_data.csv. Batch 27 time: 0:03:18 (avg: 0:02:30, remaining: 11:22:29)
# Writing temp data7
# Exported lines 2800-2899 to steampowered_app_data.csv. Batch 28 time: 0:01:38 (avg: 0:02:28, remaining: 11:11:48)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 2900-2999 to steampowered_app_data.csv. Batch 29 time: 0:03:31 (avg: 0:02:30, remaining: 11:18:50)
# Writing temp data5
# Exported lines 3000-3099 to steampowered_app_data.csv. Batch 30 time: 0:01:36 (avg: 0:02:29, remaining: 11:08:29)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 3100-3199 to steampowered_app_data.csv. Batch 31 time: 0:03:31 (avg: 0:02:30, remaining: 11:14:41)
# Writing temp data3
# Exported lines 3200-3299 to steampowered_app_data.csv. Batch 32 time: 0:01:39 (avg: 0:02:29, remaining: 11:05:15)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 3300-3399 to steampowered_app_data.csv. Batch 33 time: 0:03:23 (avg: 0:02:31, remaining: 11:09:52)
# Writing temp data1
# Exported lines 3400-3499 to steampowered_app_data.csv. Batch 34 time: 0:01:36 (avg: 0:02:29, remaining: 11:00:27)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 3500-3599 to steampowered_app_data.csv. Batch 35 time: 0:03:32 (avg: 0:02:31, remaining: 11:05:41)
# Writing temp data9
# Exported lines 3600-3699 to steampowered_app_data.csv. Batch 36 time: 0:01:38 (avg: 0:02:29, remaining: 10:56:53)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 3700-3799 to steampowered_app_data.csv. Batch 37 time: 0:03:24 (avg: 0:02:31, remaining: 11:00:43)
# Writing temp data9
# Exported lines 3800-3899 to steampowered_app_data.csv. Batch 38 time: 0:01:40 (avg: 0:02:29, remaining: 10:52:33)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 3900-3999 to steampowered_app_data.csv. Batch 39 time: 0:03:24 (avg: 0:02:31, remaining: 10:56:00)
# Writing temp data9
# Exported lines 4000-4099 to steampowered_app_data.csv. Batch 40 time: 0:01:40 (avg: 0:02:30, remaining: 10:48:08)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 4100-4199 to steampowered_app_data.csv. Batch 41 time: 0:02:51 (avg: 0:02:30, remaining: 10:47:50)
# Writing temp data3
# Exported lines 4200-4299 to steampowered_app_data.csv. Batch 42 time: 0:01:38 (avg: 0:02:29, remaining: 10:40:10)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 4300-4399 to steampowered_app_data.csv. Batch 43 time: 0:03:19 (avg: 0:02:30, remaining: 10:42:34)
# Writing temp data5
# Exported lines 4400-4499 to steampowered_app_data.csv. Batch 44 time: 0:01:42 (avg: 0:02:29, remaining: 10:35:28)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 4500-4599 to steampowered_app_data.csv. Batch 45 time: 0:03:26 (avg: 0:02:30, remaining: 10:38:14)
# Writing temp data8
# Exported lines 4600-4699 to steampowered_app_data.csv. Batch 46 time: 0:01:40 (avg: 0:02:29, remaining: 10:31:10)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 4700-4799 to steampowered_app_data.csv. Batch 47 time: 0:03:25 (avg: 0:02:30, remaining: 10:33:38)
# Writing temp data3
# Exported lines 4800-4899 to steampowered_app_data.csv. Batch 48 time: 0:01:42 (avg: 0:02:29, remaining: 10:26:58)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 4900-4999 to steampowered_app_data.csv. Batch 49 time: 0:03:28 (avg: 0:02:30, remaining: 10:29:23)
# Writing temp data2
# Exported lines 5000-5099 to steampowered_app_data.csv. Batch 50 time: 0:01:39 (avg: 0:02:29, remaining: 10:22:39)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 5100-5199 to steampowered_app_data.csv. Batch 51 time: 0:03:23 (avg: 0:02:30, remaining: 10:24:26)
# Writing temp data3
# Exported lines 5200-5299 to steampowered_app_data.csv. Batch 52 time: 0:01:37 (avg: 0:02:29, remaining: 10:17:45)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 5300-5399 to steampowered_app_data.csv. Batch 53 time: 0:03:30 (avg: 0:02:31, remaining: 10:19:53)
# Writing temp data0
# Exported lines 5400-5499 to steampowered_app_data.csv. Batch 54 time: 0:01:36 (avg: 0:02:30, remaining: 10:13:17)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 5500-5599 to steampowered_app_data.csv. Batch 55 time: 0:03:24 (avg: 0:02:31, remaining: 10:14:47)
# Writing temp data2
# Exported lines 5600-5699 to steampowered_app_data.csv. Batch 56 time: 0:01:37 (avg: 0:02:30, remaining: 10:08:26)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 5700-5799 to steampowered_app_data.csv. Batch 57 time: 0:03:31 (avg: 0:02:31, remaining: 10:10:12)
# Writing temp data7
# Exported lines 5800-5899 to steampowered_app_data.csv. Batch 58 time: 0:01:38 (avg: 0:02:30, remaining: 10:04:04)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 5900-5999 to steampowered_app_data.csv. Batch 59 time: 0:03:25 (avg: 0:02:31, remaining: 10:05:15)
# Writing temp data5
# Exported lines 6000-6099 to steampowered_app_data.csv. Batch 60 time: 0:01:40 (avg: 0:02:30, remaining: 9:59:26)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 6100-6199 to steampowered_app_data.csv. Batch 61 time: 0:03:22 (avg: 0:02:31, remaining: 10:00:15)
# Writing temp data7
# Exported lines 6200-6299 to steampowered_app_data.csv. Batch 62 time: 0:01:36 (avg: 0:02:30, remaining: 9:54:18)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data8
# Exported lines 6300-6399 to steampowered_app_data.csv. Batch 63 time: 0:03:32 (avg: 0:02:31, remaining: 9:55:36)
# Writing temp data6
# Exported lines 6400-6499 to steampowered_app_data.csv. Batch 64 time: 0:01:40 (avg: 0:02:30, remaining: 9:50:00)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 6500-6599 to steampowered_app_data.csv. Batch 65 time: 0:03:21 (avg: 0:02:31, remaining: 9:50:30)
# Writing temp data7
# Exported lines 6600-6699 to steampowered_app_data.csv. Batch 66 time: 0:01:36 (avg: 0:02:30, remaining: 9:44:47)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 6700-6799 to steampowered_app_data.csv. Batch 67 time: 0:03:31 (avg: 0:02:31, remaining: 9:45:45)
# Writing temp data3
# Exported lines 6800-6899 to steampowered_app_data.csv. Batch 68 time: 0:01:36 (avg: 0:02:30, remaining: 9:40:10)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 6900-6999 to steampowered_app_data.csv. Batch 69 time: 0:03:31 (avg: 0:02:31, remaining: 9:41:00)
# Writing temp data4
# Exported lines 7000-7099 to steampowered_app_data.csv. Batch 70 time: 0:01:40 (avg: 0:02:30, remaining: 9:35:44)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 7100-7199 to steampowered_app_data.csv. Batch 71 time: 0:03:22 (avg: 0:02:31, remaining: 9:35:57)
# Writing temp data2
# Exported lines 7200-7299 to steampowered_app_data.csv. Batch 72 time: 0:01:37 (avg: 0:02:30, remaining: 9:30:37)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 7300-7399 to steampowered_app_data.csv. Batch 73 time: 0:03:32 (avg: 0:02:31, remaining: 9:31:16)
# Writing temp data6
# Exported lines 7400-7499 to steampowered_app_data.csv. Batch 74 time: 0:01:35 (avg: 0:02:30, remaining: 9:25:57)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 7500-7599 to steampowered_app_data.csv. Batch 75 time: 0:03:31 (avg: 0:02:31, remaining: 9:26:28)
# Writing temp data8
# Exported lines 7600-7699 to steampowered_app_data.csv. Batch 76 time: 0:01:36 (avg: 0:02:30, remaining: 9:21:16)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 7700-7799 to steampowered_app_data.csv. Batch 77 time: 0:03:31 (avg: 0:02:31, remaining: 9:21:39)
# Writing temp data3
# Exported lines 7800-7899 to steampowered_app_data.csv. Batch 78 time: 0:01:36 (avg: 0:02:30, remaining: 9:16:32)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 7900-7999 to steampowered_app_data.csv. Batch 79 time: 0:03:31 (avg: 0:02:31, remaining: 9:16:50)
# Writing temp data9
# Exported lines 8000-8099 to steampowered_app_data.csv. Batch 80 time: 0:01:37 (avg: 0:02:31, remaining: 9:11:52)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data8
# Exported lines 8100-8199 to steampowered_app_data.csv. Batch 81 time: 0:03:30 (avg: 0:02:31, remaining: 9:11:59)
# Writing temp data3
# Exported lines 8200-8299 to steampowered_app_data.csv. Batch 82 time: 0:01:38 (avg: 0:02:31, remaining: 9:07:10)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data8
# Exported lines 8300-8399 to steampowered_app_data.csv. Batch 83 time: 0:03:30 (avg: 0:02:31, remaining: 9:07:13)
# Writing temp data5
# Exported lines 8400-8499 to steampowered_app_data.csv. Batch 84 time: 0:01:38 (avg: 0:02:31, remaining: 9:02:26)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data9
# Exported lines 8500-8599 to steampowered_app_data.csv. Batch 85 time: 0:03:31 (avg: 0:02:31, remaining: 9:02:25)
# Writing temp data7
# Exported lines 8600-8699 to steampowered_app_data.csv. Batch 86 time: 0:01:39 (avg: 0:02:31, remaining: 8:57:44)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 8700-8799 to steampowered_app_data.csv. Batch 87 time: 0:03:20 (avg: 0:02:31, remaining: 8:57:12)
# Writing temp data2
# Exported lines 8800-8899 to steampowered_app_data.csv. Batch 88 time: 0:01:39 (avg: 0:02:31, remaining: 8:52:37)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 8900-8999 to steampowered_app_data.csv. Batch 89 time: 0:03:22 (avg: 0:02:31, remaining: 8:52:07)
# Writing temp data6
# Exported lines 9000-9099 to steampowered_app_data.csv. Batch 90 time: 0:01:41 (avg: 0:02:31, remaining: 8:47:40)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 9100-9199 to steampowered_app_data.csv. Batch 91 time: 0:03:22 (avg: 0:02:31, remaining: 8:47:06)
# Writing temp data0
# Exported lines 9200-9299 to steampowered_app_data.csv. Batch 92 time: 0:01:43 (avg: 0:02:31, remaining: 8:42:46)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 9300-9399 to steampowered_app_data.csv. Batch 93 time: 0:03:20 (avg: 0:02:31, remaining: 8:42:04)
# Writing temp data2
# Exported lines 9400-9499 to steampowered_app_data.csv. Batch 94 time: 0:01:38 (avg: 0:02:31, remaining: 8:37:37)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 9500-9599 to steampowered_app_data.csv. Batch 95 time: 0:03:27 (avg: 0:02:31, remaining: 8:37:06)
# Writing temp data8
# Exported lines 9600-9699 to steampowered_app_data.csv. Batch 96 time: 0:01:41 (avg: 0:02:31, remaining: 8:32:48)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 9700-9799 to steampowered_app_data.csv. Batch 97 time: 0:03:23 (avg: 0:02:31, remaining: 8:32:06)
# Writing temp data1
# Exported lines 9800-9899 to steampowered_app_data.csv. Batch 98 time: 0:01:40 (avg: 0:02:31, remaining: 8:27:49)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 9900-9999 to steampowered_app_data.csv. Batch 99 time: 0:03:24 (avg: 0:02:31, remaining: 8:27:05)
# Writing temp data2
# Exported lines 10000-10099 to steampowered_app_data.csv. Batch 100 time: 0:01:42 (avg: 0:02:31, remaining: 8:22:56)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data
# Exported lines 10100-10199 to steampowered_app_data.csv. Batch 101 time: 0:03:21 (avg: 0:02:31, remaining: 8:22:03)
# Writing temp data0
# Exported lines 10200-10299 to steampowered_app_data.csv. Batch 102 time: 0:01:46 (avg: 0:02:31, remaining: 8:18:03)
# Writing temp data0
# Exported lines 10300-10399 to steampowered_app_data.csv. Batch 103 time: 0:01:45 (avg: 0:02:30, remaining: 8:14:04)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 10400-10499 to steampowered_app_data.csv. Batch 104 time: 0:03:20 (avg: 0:02:31, remaining: 8:13:06)
# Writing temp data9
# Exported lines 10500-10599 to steampowered_app_data.csv. Batch 105 time: 0:01:42 (avg: 0:02:30, remaining: 8:09:05)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 10600-10699 to steampowered_app_data.csv. Batch 106 time: 0:03:13 (avg: 0:02:31, remaining: 8:07:51)
# Writing temp data0
# Exported lines 10700-10799 to steampowered_app_data.csv. Batch 107 time: 0:01:42 (avg: 0:02:30, remaining: 8:03:53)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data4
# Exported lines 10800-10899 to steampowered_app_data.csv. Batch 108 time: 0:03:22 (avg: 0:02:31, remaining: 8:02:53)
# Writing temp data3
# Exported lines 10900-10999 to steampowered_app_data.csv. Batch 109 time: 0:01:41 (avg: 0:02:30, remaining: 7:58:55)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 11000-11099 to steampowered_app_data.csv. Batch 110 time: 0:03:26 (avg: 0:02:31, remaining: 7:58:00)
# Writing temp data9
# Exported lines 11100-11199 to steampowered_app_data.csv. Batch 111 time: 0:01:37 (avg: 0:02:30, remaining: 7:53:58)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 11200-11299 to steampowered_app_data.csv. Batch 112 time: 0:03:23 (avg: 0:02:31, remaining: 7:52:56)
# Writing temp data2
# Exported lines 11300-11399 to steampowered_app_data.csv. Batch 113 time: 0:01:37 (avg: 0:02:30, remaining: 7:48:57)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 11400-11499 to steampowered_app_data.csv. Batch 114 time: 0:03:21 (avg: 0:02:31, remaining: 7:47:48)
# Writing temp data2
# Exported lines 11500-11599 to steampowered_app_data.csv. Batch 115 time: 0:01:37 (avg: 0:02:30, remaining: 7:43:51)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data9
# Exported lines 11600-11699 to steampowered_app_data.csv. Batch 116 time: 0:03:33 (avg: 0:02:31, remaining: 7:42:59)
# Writing temp data9
# Exported lines 11700-11799 to steampowered_app_data.csv. Batch 117 time: 0:01:36 (avg: 0:02:31, remaining: 7:39:03)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 11800-11899 to steampowered_app_data.csv. Batch 118 time: 0:03:30 (avg: 0:02:31, remaining: 7:38:04)
# Writing temp data9
# Exported lines 11900-11999 to steampowered_app_data.csv. Batch 119 time: 0:01:39 (avg: 0:02:31, remaining: 7:34:15)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 12000-12099 to steampowered_app_data.csv. Batch 120 time: 0:03:25 (avg: 0:02:31, remaining: 7:33:05)
# Writing temp data3
# Exported lines 12100-12199 to steampowered_app_data.csv. Batch 121 time: 0:01:40 (avg: 0:02:31, remaining: 7:29:19)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 12200-12299 to steampowered_app_data.csv. Batch 122 time: 0:03:21 (avg: 0:02:31, remaining: 7:28:01)
# Writing temp data6
# Exported lines 12300-12399 to steampowered_app_data.csv. Batch 123 time: 0:01:34 (avg: 0:02:31, remaining: 7:24:09)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 12400-12499 to steampowered_app_data.csv. Batch 124 time: 0:03:46 (avg: 0:02:31, remaining: 7:23:25)
# Writing temp data1
# Exported lines 12500-12599 to steampowered_app_data.csv. Batch 125 time: 0:01:48 (avg: 0:02:31, remaining: 7:19:53)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data0
# Exported lines 12600-12699 to steampowered_app_data.csv. Batch 126 time: 0:03:13 (avg: 0:02:31, remaining: 7:18:20)
# Writing temp data4
# Exported lines 12700-12799 to steampowered_app_data.csv. Batch 127 time: 0:01:45 (avg: 0:02:31, remaining: 7:14:47)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 12800-12899 to steampowered_app_data.csv. Batch 128 time: 0:03:09 (avg: 0:02:31, remaining: 7:13:07)
# Writing temp data2
# Exported lines 12900-12999 to steampowered_app_data.csv. Batch 129 time: 0:01:36 (avg: 0:02:31, remaining: 7:09:23)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 13000-13099 to steampowered_app_data.csv. Batch 130 time: 0:02:47 (avg: 0:02:31, remaining: 7:07:14)
# Writing temp data8
# Exported lines 13100-13199 to steampowered_app_data.csv. Batch 131 time: 0:01:39 (avg: 0:02:30, remaining: 7:03:37)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 13200-13299 to steampowered_app_data.csv. Batch 132 time: 0:03:14 (avg: 0:02:31, remaining: 7:02:01)
# Writing temp data3
# Exported lines 13300-13399 to steampowered_app_data.csv. Batch 133 time: 0:01:38 (avg: 0:02:30, remaining: 6:58:25)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 13400-13499 to steampowered_app_data.csv. Batch 134 time: 0:03:24 (avg: 0:02:31, remaining: 6:57:01)
# Writing temp data6
# Exported lines 13500-13599 to steampowered_app_data.csv. Batch 135 time: 0:01:37 (avg: 0:02:30, remaining: 6:53:25)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 13600-13699 to steampowered_app_data.csv. Batch 136 time: 0:03:30 (avg: 0:02:31, remaining: 6:52:06)
# Writing temp data4
# Exported lines 13700-13799 to steampowered_app_data.csv. Batch 137 time: 0:01:41 (avg: 0:02:30, remaining: 6:48:37)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 13800-13899 to steampowered_app_data.csv. Batch 138 time: 0:03:18 (avg: 0:02:31, remaining: 6:47:02)
# Writing temp data8
# Exported lines 13900-13999 to steampowered_app_data.csv. Batch 139 time: 0:01:37 (avg: 0:02:30, remaining: 6:43:29)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 14000-14099 to steampowered_app_data.csv. Batch 140 time: 0:03:32 (avg: 0:02:31, remaining: 6:42:09)
# Writing temp data8
# Exported lines 14100-14199 to steampowered_app_data.csv. Batch 141 time: 0:01:43 (avg: 0:02:30, remaining: 6:38:45)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data9
# Exported lines 14200-14299 to steampowered_app_data.csv. Batch 142 time: 0:03:23 (avg: 0:02:31, remaining: 6:37:13)
# Writing temp data1
# Exported lines 14300-14399 to steampowered_app_data.csv. Batch 143 time: 0:01:34 (avg: 0:02:30, remaining: 6:33:41)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data9
# Exported lines 14400-14499 to steampowered_app_data.csv. Batch 144 time: 0:03:29 (avg: 0:02:31, remaining: 6:32:13)
# Writing temp data3
# Exported lines 14500-14599 to steampowered_app_data.csv. Batch 145 time: 0:01:38 (avg: 0:02:30, remaining: 6:28:45)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 14600-14699 to steampowered_app_data.csv. Batch 146 time: 0:03:31 (avg: 0:02:31, remaining: 6:27:18)
# Writing temp data7
# Exported lines 14700-14799 to steampowered_app_data.csv. Batch 147 time: 0:01:35 (avg: 0:02:31, remaining: 6:23:49)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 14800-14899 to steampowered_app_data.csv. Batch 148 time: 0:03:33 (avg: 0:02:31, remaining: 6:22:23)
# Writing temp data3
# Exported lines 14900-14999 to steampowered_app_data.csv. Batch 149 time: 0:01:36 (avg: 0:02:31, remaining: 6:18:57)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 15000-15099 to steampowered_app_data.csv. Batch 150 time: 0:03:29 (avg: 0:02:31, remaining: 6:17:24)
# Writing temp data3
# Exported lines 15100-15199 to steampowered_app_data.csv. Batch 151 time: 0:01:39 (avg: 0:02:31, remaining: 6:14:02)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 15200-15299 to steampowered_app_data.csv. Batch 152 time: 0:03:28 (avg: 0:02:31, remaining: 6:12:26)
# Writing temp data9
# Exported lines 15300-15399 to steampowered_app_data.csv. Batch 153 time: 0:01:35 (avg: 0:02:31, remaining: 6:09:02)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 15400-15499 to steampowered_app_data.csv. Batch 154 time: 0:03:28 (avg: 0:02:31, remaining: 6:07:25)
# Writing temp data1
# Exported lines 15500-15599 to steampowered_app_data.csv. Batch 155 time: 0:01:35 (avg: 0:02:31, remaining: 6:04:02)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data5
# Exported lines 15600-15699 to steampowered_app_data.csv. Batch 156 time: 0:03:30 (avg: 0:02:31, remaining: 6:02:26)
# Writing temp data2
# Exported lines 15700-15799 to steampowered_app_data.csv. Batch 157 time: 0:01:39 (avg: 0:02:31, remaining: 5:59:08)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data8
# Exported lines 15800-15899 to steampowered_app_data.csv. Batch 158 time: 0:03:22 (avg: 0:02:31, remaining: 5:57:23)
# Writing temp data5
# Exported lines 15900-15999 to steampowered_app_data.csv. Batch 159 time: 0:01:38 (avg: 0:02:31, remaining: 5:54:05)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 16000-16099 to steampowered_app_data.csv. Batch 160 time: 0:03:26 (avg: 0:02:31, remaining: 5:52:23)
# Writing temp data9
# Exported lines 16100-16199 to steampowered_app_data.csv. Batch 161 time: 0:01:35 (avg: 0:02:31, remaining: 5:49:04)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 16200-16299 to steampowered_app_data.csv. Batch 162 time: 0:03:30 (avg: 0:02:31, remaining: 5:47:23)
# Writing temp data8
# Exported lines 16300-16399 to steampowered_app_data.csv. Batch 163 time: 0:01:37 (avg: 0:02:31, remaining: 5:44:07)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data1
# Exported lines 16400-16499 to steampowered_app_data.csv. Batch 164 time: 0:03:31 (avg: 0:02:31, remaining: 5:42:26)
# Writing temp data1
# Exported lines 16500-16599 to steampowered_app_data.csv. Batch 165 time: 0:01:36 (avg: 0:02:31, remaining: 5:39:10)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data2
# Exported lines 16600-16699 to steampowered_app_data.csv. Batch 166 time: 0:03:31 (avg: 0:02:31, remaining: 5:37:28)
# Writing temp data8
# Exported lines 16700-16799 to steampowered_app_data.csv. Batch 167 time: 0:01:39 (avg: 0:02:31, remaining: 5:34:16)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data6
# Exported lines 16800-16899 to steampowered_app_data.csv. Batch 168 time: 0:03:24 (avg: 0:02:31, remaining: 5:32:27)
# Writing temp data3
# Exported lines 16900-16999 to steampowered_app_data.csv. Batch 169 time: 0:01:34 (avg: 0:02:31, remaining: 5:29:11)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 17000-17099 to steampowered_app_data.csv. Batch 170 time: 0:03:28 (avg: 0:02:31, remaining: 5:27:24)
# Writing temp data1
# Exported lines 17100-17199 to steampowered_app_data.csv. Batch 171 time: 0:01:37 (avg: 0:02:31, remaining: 5:24:12)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data7
# Exported lines 17200-17299 to steampowered_app_data.csv. Batch 172 time: 0:03:32 (avg: 0:02:31, remaining: 5:22:27)
# Writing temp data6
# Exported lines 17300-17399 to steampowered_app_data.csv. Batch 173 time: 0:01:34 (avg: 0:02:31, remaining: 5:19:15)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Writing temp data3
# Exported lines 17400-17499 to steampowered_app_data.csv. Batch 174 time: 0:03:28 (avg: 0:02:31, remaining: 5:17:25)
# Writing temp data3
# Exported lines 17500-17599 to steampowered_app_data.csv. Batch 175 time: 0:01:41 (avg: 0:02:31, remaining: 5:14:18)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
